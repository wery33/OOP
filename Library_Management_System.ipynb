# %%
class Book:
    def __init__(self, title, author, year):
        self. title = title
        self.author= author
        self.year = year

    def info(self):
        print(f"Title : {self.title}")
        print(f"Author : {self.author}")
        print(f"Year : {self.year}")
 


class FictionBook(Book):
    def __init__(self, title, author, year, genre):
        super().__init__(  title, author, year)
        self.genre = genre

    def info(self):      
        super().info() #this prints out all things in the book_info() method
        print(f"Genre : {self.genre}")
        print()

class NonFictionBook(Book):
    def __init__(self, title, author, year, topic):
        super().__init__(title, author, year)
        self.topic = topic
        
    def info(self):
        super().info()
        print(f"Topic : {self.topic}")
            

#Creating a library like a database to hold only all books and this is a class

class Library:
    def __init__(self):
        self.books = []

    def add_books(self):
        num = int(input("Enter the number of books: "))
        print(f"Name {num} books: \t")
        for _ in range(num):
            book = input("Enter a book")
            self.books.append(book)
        for i in self.books:
            print(i)
            
    def add_book(self, book):
        self.books.append(book)

    def display_books(self):
        for book in self.books:
            book.info()
            print()

    def search_author(self, author):
        found_books = []
        for book in self.books:
            if book.author == author:
                found_books.append(book)
        if found_books:
            print(f"Books by {author}:")
            book.info()
            print()
        else:
            print("No books found by this author")

    def search_year(self, start_year, end_year):
        found_books = []
        for book in self.books:
            if start_year <= book.year <= end_year:
                found_books.append(book)
        if found_books:
            print(f"Books between {start_year} and {end_year}")
            for book in found_books:
                book.info()
                print()
        else:
            print("Error!!")
            
    
library = Library()

book1 = FictionBook("Harry Porter", "J.K Rowling", 1997, "Fantasy")
book2 = FictionBook("The Great Gatsby", "F Scott", 1925, "Classic")
book3 = NonFictionBook("Sapiens: A Brief History of Humankind", "Yuval Noah Harari", 2014, "Anthropology")
book4 = NonFictionBook("The Power of Now", "Eckhart Tolle", 1997, "Spiritual")
library.add_book(book1)
library.add_book(book2)
library.add_book(book3)
library.add_book(book4)

library.display_books()
library.search_author("F. Scotts")
library.search_year(2000, 2020)



print()
print()

print("----------------------------------------------------------------------")

main = Book("Zedek Admit" , "Kofi", "2014")
main.info()
print()

harry_potter = Book("Harry Potter","Doons Day", "2005")
harry_potter.info()
print()


Patrick = FictionBook("Patan Series", "Patrick Ansah" , "2012", "Science")
Patrick.info()
print()

Anna = NonFictionBook("Senior Analyst Book", "Anna Bryant","2015","Business Analysis")
Anna.info()

bee = Library()
bee.add_books()
# Out:
# Title : Harry Porter
# Author : J.K Rowling
# Year : 1997
# Genre : Fantasy
#
#
# Title : The Great Gatsby
# Author : F Scott
# Year : 1925
# Genre : Classic
#
#
# Title : Sapiens: A Brief History of Humankind
# Author : Yuval Noah Harari
# Year : 2014
# Topic : Anthropology
#
# Title : The Power of Now
# Author : Eckhart Tolle
# Year : 1997
# Topic : Spiritual
#
# No books found by this author
# Books between 2000 and 2020
# Title : Sapiens: A Brief History of Humankind
# Author : Yuval Noah Harari
# Year : 2014
# Topic : Anthropology
#
#
#
# ----------------------------------------------------------------------
# Title : Zedek Admit
# Author : Kofi
# Year : 2014
#
# Title : Harry Potter
# Author : Doons Day
# Year : 2005
#
# Title : Patan Series
# Author : Patrick Ansah
# Year : 2012
# Genre : Science
#
#
# Title : Senior Analyst Book
# Author : Anna Bryant
# Year : 2015
# Topic : Business Analysis
# Enter the number of books:  1
# Name 1 books:
# Enter a book fjkgkf
# fjkgkf
